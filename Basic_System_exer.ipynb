# %% [markdown]
# # 시스템 설정 알아보기

# %% [markdown]
# **1. 구글 드라이브 사용하기 위한 설정**

# %%
from google.colab import drive

drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# **2. 파이썬 버젼 확인하기**

# %%
import sys

sys.version_info
# Out:
# sys.version_info(major=3, minor=6, micro=8, releaselevel='final', serial=0)

# %% [markdown]
# > 파이썬 3, version 3.6.8 버젼임을 나타냄

# %% [markdown]
# **3. OS 플랫폼 확인하기**

# %%
import platform

platform.platform()
# Out:
# 'Linux-4.14.79+-x86_64-with-Ubuntu-18.04-bionic'

# %%
# 환경 변수 확인하기
# %env TEST="True"
# %env
# Out:
# env: TEST="True"
# {'CLICOLOR': '1',
#  'CLOUDSDK_CONFIG': '/content/.config',
#  'COLAB_GPU': '0',
#  'CUDA_PKG_VERSION': '10-1=10.1.243-1',
#  'CUDA_VERSION': '10.1.243',
#  'CUDNN_VERSION': '7.6.5.32',
#  'DATALAB_SETTINGS_OVERRIDES': '{"kernelManagerProxyPort":6000,"kernelManagerProxyHost":"172.28.0.3","jupyterArgs":["--ip=\\"172.28.0.2\\""]}',
#  'DEBIAN_FRONTEND': 'noninteractive',
#  'ENV': '/root/.bashrc',
#  'GCS_READ_CACHE_BLOCK_SIZE_MB': '16',
#  'GIT_PAGER': 'cat',
#  'GLIBCPP_FORCE_NEW': '1',
#  'GLIBCXX_FORCE_NEW': '1',
#  'HOME': '/root',
#  'HOSTNAME': '98069c874049',
#  'JPY_PARENT_PID': '25',
#  'LANG': 'en_US.UTF-8',
#  'LAST_FORCED_REBUILD': '20191217',
#  'LD_LIBRARY_PATH': '/usr/local/nvidia/lib:/usr/local/nvidia/lib64',
#  'LD_PRELOAD': '/usr/lib/x86_64-linux-gnu/libtcmalloc.so.4',
#  'LIBRARY_PATH': '/usr/local/cuda/lib64/stubs',
#  'MPLBACKEND': 'module://ipykernel.pylab.backend_inline',
#  'NCCL_VERSION': '2.4.8',
#  'NO_GCE_CHECK': 'True',
#  'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility',
#  'NVIDIA_REQUIRE_CUDA': 'cuda>=10.1 brand=tesla,driver>=384,driver<385 brand=tesla,driver>=396,driver<397 brand=tesla,driver>=410,driver<411',
#  'NVIDIA_VISIBLE_DEVICES': 'all',
#  'OLDPWD': '/',
#  'PAGER': 'cat',
#  'PATH': '/usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/tools/node/bin:/tools/google-cloud-sdk/bin:/opt/bin',
#  'PWD': '/',
#  'PYTHONPATH': '/env/python',
#  'PYTHONWARNINGS': 'ignore:::pip._internal.cli.base_command',
#  'SHELL': '/bin/bash',
#  'SHLVL': '1',
#  'TBE_CREDS_ADDR': '172.28.0.1:8008',
#  'TERM': 'xterm-color',
#  'TEST': '"True"',
#  'TF_FORCE_GPU_ALLOW_GROWTH': 'true',
#  '_': '/tools/node/bin/node'}

# %% [markdown]
# > 우부투 18.04 버전

# %% [markdown]
# **4. 설치된 패키지 확인하기**

# %%
# !pip freeze

# %%
# !pip list |grep pandas
# Out:
# pandas                   0.25.3
# pandas-datareader        0.7.4
# pandas-gbq               0.11.0
# pandas-profiling         1.4.1
# sklearn-pandas           1.8.0

# %%
# !pip show tensorflow

# %% [markdown]
# # 디젝토리 작업하기

# %% [markdown]
# **1. 현재 디렉토리 보기**

# %%
import os

print(os.getcwd())
# Out:
# /content/drive/My Drive/Colab Notebooks/Exercise/pydata/02_examples

# %% [markdown]
# **2. 디렉토리 변경하기**

# %%
os.chdir('/content/drive/My Drive/Colab Notebooks/Exercise/pydata/02_examples')

# %%
os.chdir('../')

# %% [markdown]
# # % run 명령 알아보기

# %% [markdown]
# **1. 기본 사용법**

# %%
# %run test.py
# Out:
# ERROR:root:File `'test.py'` not found.

# %%
# 코드 실행 시간 측정하기
import numpy as np

# %timeit np.random.normal(size=100)
# Out:
# The slowest run took 90.89 times longer than the fastest. This could mean that an intermediate result is being cached.
# 100000 loops, best of 3: 8.36 µs per loop

# %%
c
# Out:
# 7.5

# %%
result
# Out:
# 1.4666666666666666

# %%
ip_info = !ifconfig eth0 | grep "inet"

# %%
ip_info[0]
# Out:
# '/bin/bash: ifconfig: command not found'

# %% [markdown]
# # 디버깅 하는 방법 알아보기

# %% [markdown]
# **1. 디버깅 따라해보기**

# %%
run ipython_bug.py
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /content/drive/My Drive/Colab Notebooks/Exercise/pydata/02_examples/ipython_bug.py in <module>()
#      13     throws_an_exception()
#      14
# ---> 15 calling_things()
#
# /content/drive/My Drive/Colab Notebooks/Exercise/pydata/02_examples/ipython_bug.py in calling_things()
#      11 def calling_things():
#      12     works_fine()
# ---> 13     throws_an_exception()
#      14
#      15 calling_things()
#
# /content/drive/My Drive/Colab Notebooks/Exercise/pydata/02_examples/ipython_bug.py in throws_an_exception()
#       7     a = 5
#       8     b = 6
# ----> 9     assert(a + b == 10)
#      10
#      11 def calling_things():
#
# AssertionError:

# %% [markdown]
# **1.  %debug 명령어 사용해보기
#
#
# > 디폴트로 오류가 발생한 가장 아래 레벨에서 시작한다고 함
#
# >u(up), d(down), c(continue), b 숫자 (break number), s(step), n(next)

# %%
# %debug
# Out:
# > /content/gdrive/My Drive/Colab Notebooks/Exercise/pydata/02_examples/ipython_bug.py(9)throws_an_exception()
#
# ipdb> u
# > /content/gdrive/My Drive/Colab Notebooks/Exercise/pydata/02_examples/ipython_bug.py(13)calling_things()
#
# ipdb> d
# > /content/gdrive/My Drive/Colab Notebooks/Exercise/pydata/02_examples/ipython_bug.py(9)throws_an_exception()
#
# ipdb> d
# *** Newest frame
# --KeyboardInterrupt--
# ipdb> c

# %% [markdown]
# **1.2. run -d 옵션**
#
# *스크립트를 실행하기전에 디버거를 먼저 시작한다고 하는데 이것 역시 아직은 어렵다.*

# %%
run -d ipython_bug.py
# Out:
# Breakpoint 1 at /content/drive/My Drive/Colab Notebooks/Exercise/pydata/02_examples/ipython_bug.py:1
# NOTE: Enter 'c' at the ipdb>  prompt to continue execution.
# > /content/drive/My Drive/Colab Notebooks/Exercise/pydata/02_examples/ipython_bug.py(1)<module>()
# 1---> 1 def works_fine():
#       2     a = 5
#       3     b = 6
#       4     assert(a + b == 11)
#       5
#
# ipdb> b 12
# Breakpoint 2 at /content/drive/My Drive/Colab Notebooks/Exercise/pydata/02_examples/ipython_bug.py:12
# ipdb> c
# > /content/drive/My Drive/Colab Notebooks/Exercise/pydata/02_examples/ipython_bug.py(12)calling_things()
#      10
#      11 def calling_things():
# 2--> 12     works_fine()
#      13     throws_an_exception()
#      14
#
# ipdb> s
# --Call--
# > /content/drive/My Drive/Colab Notebooks/Exercise/pydata/02_examples/ipython_bug.py(1)works_fine()
# 1---> 1 def works_fine():
#       2     a = 5
#       3     b = 6
#       4     assert(a + b == 11)
#       5
#
# ipdb> n
# > /content/drive/My Drive/Colab Notebooks/Exercise/pydata/02_examples/ipython_bug.py(2)works_fine()
# 1     1 def works_fine():
# ----> 2     a = 5
#       3     b = 6
#       4     assert(a + b == 11)
#       5
#
# ipdb> n
# > /content/drive/My Drive/Colab Notebooks/Exercise/pydata/02_examples/ipython_bug.py(3)works_fine()
# 1     1 def works_fine():
#       2     a = 5
# ----> 3     b = 6
#       4     assert(a + b == 11)
#       5
#
# ipdb> n
# > /content/drive/My Drive/Colab Notebooks/Exercise/pydata/02_examples/ipython_bug.py(4)works_fine()
#       2     a = 5
#       3     b = 6
# ----> 4     assert(a + b == 11)
#       5
#       6 def throws_an_exception():
#
# ipdb> !a
# 5
# ipdb> !b
# 6
# ipdb> c
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py in safe_execfile(self, fname, *where, **kw)
#    2481                 py3compat.execfile(
#    2482                     fname, glob, loc,
# -> 2483                     self.compile if kw['shell_futures'] else None)
#    2484             except SystemExit as status:
#    2485                 # If the call was made with 0 or None exit status (sys.exit(0)
#
# /usr/local/lib/python3.6/dist-packages/IPython/utils/py3compat.py in execfile(fname, glob, loc, compiler)
#     184         with open(fname, 'rb') as f:
#     185             compiler = compiler or compile
# --> 186             exec(compiler(f.read(), fname, 'exec'), glob, loc)
#     187
#     188     # Refactor print statements in doctests.
#
# /content/drive/My Drive/Colab Notebooks/Exercise/pydata/02_examples/ipython_bug.py in <module>()
#      13     throws_an_exception()
#      14
# ---> 15 calling_things()
#
# /content/drive/My Drive/Colab Notebooks/Exercise/pydata/02_examples/ipython_bug.py in calling_things()
#      11 def calling_things():
#      12     works_fine()
# ---> 13     throws_an_exception()
#      14
#      15 calling_things()
#
# /content/drive/My Drive/Colab Notebooks/Exercise/pydata/02_examples/ipython_bug.py in throws_an_exception()
#       7     a = 5
#       8     b = 6
# ----> 9     assert(a + b == 10)
#      10
#      11 def calling_things():
#
# AssertionError:
